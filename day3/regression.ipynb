# %% [markdown]
# The first version is using numpy

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample dataset
X = np.array([1, 2, 3, 4, 5])
y = np.array([3, 4, 2, 5, 6])

# Calculate slope (m) and intercept (c)
n = len(X)
m = (n*np.sum(X*y) - np.sum(X)*np.sum(y)) / (n*np.sum(X**2) - (np.sum(X))**2)
c = (np.sum(y) - m*np.sum(X)) / n

print("Slope:", m)
print("Intercept:", c)

# Predict values
y_pred = m*X + c

# Plot
plt.scatter(X, y, label="Actual")
plt.plot(X, y_pred, color="red", label="Regression Line")
plt.legend()
plt.show()
# Out:
# Slope: 0.7
# Intercept: 1.9

# %% [markdown]
# The next version is using scikit-learn

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Data
X = np.array([[1], [2], [3], [4], [5]])  # 2D for sklearn
y = np.array([3, 4, 2, 5, 6])

# Model
model = LinearRegression()
model.fit(X, y)

# Parameters
print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)

# Prediction
print("Prediction for x=6:", model.predict([[6]]))
# Out:
# Slope: 0.6999999999999998
# Intercept: 1.9000000000000004
# Prediction for x=6: [6.1]
